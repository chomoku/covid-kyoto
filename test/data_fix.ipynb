# %%
# !pip install plotly
# Out:
# ^C
# WARNING: You are using pip version 20.2.3; however, version 21.2.4 is available.
# You should consider upgrading via the 'c:\users\hogaw\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.
# ...

# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv('../data/kyoto_covid_patient.csv', index_col=0, parse_dates=['date']).sort_values('date').reset_index(drop=True)
df.head()
# Out:
#     事例        発表日  年代  性別 居住地等                           資料       date  age
# 0  1例目  令和2年1月30日  20  女性  京都市  厚生労働省報道資料（令和2年1月30日）（外部リンク） 2020-01-30  20代
# 1  2例目   令和2年2月5日  20  男性  京都市   厚生労働省報道資料（令和2年2月5日）（外部リンク） 2020-02-05  20代
# 2  3例目   令和2年3月3日  50  女性  京都市   京都市報道発表資料（令和2年3月3日）（外部リンク） 2020-03-03  50代
# 3  4例目   令和2年3月4日  50  女性  京都市   京都市報道発表資料（令和2年3月4日）（外部リンク） 2020-03-04  50代
# 4  5例目   令和2年3月4日  50  男性  京都市   京都市報道発表資料（令和2年3月4日）（外部リンク） 2020-03-04  50代

# %%
df = df[['date', 'age']]
df
# Out:
#             date  age
# 0     2020-01-30  20代
# 1     2020-02-05  20代
# 2     2020-03-03  50代
# 3     2020-03-04  50代
# 4     2020-03-04  50代
# ...          ...  ...
# 34649 2021-09-16  20代
# 34650 2021-09-16  30代
# 34651 2021-09-16  30代
# 34652 2021-09-16  70代
# 34653 2021-09-16  20代
#
# [34654 rows x 2 columns]

# %%
df.to_csv('../data/kyoto_covid2.csv', index=None)

# %%
df.to_csv('../data/vac_forecast.csv', index=None)

# %%
df = pd.read_csv('../data/vaccined_num.csv')

# %%
df
# Out:
#          年代  1回目接種数  1回目接種率  2回目接種数  2回目接種率                 date
# 0        全体  637565   45.23  497224   35.27           2021-08-25
# 1     65歳以上  342230   86.59  324095   82.00           2021-08-25
# 2   60歳～64歳   50021   66.57   34377   45.75           2021-08-25
# 3   50歳～59歳   86301   46.98   52587   28.63           2021-08-25
# 4   40歳～49歳   66372   31.75   37759   18.06           2021-08-25
# 5   30歳～39歳   40322   24.88   22270   13.74           2021-08-25
# 6   20歳～29歳   39428   24.32   20849   12.86           2021-08-25
# 7   12歳～19歳    9817   10.22    3654    3.80           2021-08-25
# 8        全体  643224   45.63  503803   35.74  2021-08-26 00:00:00
# 9     65歳以上  342720   86.72  325005   82.23  2021-08-26 00:00:00
# 10  60歳～64歳   50362   67.02   35055   46.65  2021-08-26 00:00:00
# 11  50歳～59歳   87883   47.84   54359   29.59  2021-08-26 00:00:00
# 12  40歳～49歳   68099   32.57   39277   18.79  2021-08-26 00:00:00
# ...
